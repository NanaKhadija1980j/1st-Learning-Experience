# %% [markdown]
# ### Analysis of Water Potability

# %%
# Read the data into a dataframe
# I will import a data analysis package

# %%
import pandas as pd # Importing Pandas

# %%
data_water = pd.read_csv('water_potability.csv') # Reading a dataset

# %%
data_water.head() # The first 5 Rows
# Out:
#          ph    Hardness        Solids  Chloramines     Sulfate  Conductivity  \
# 0       NaN  204.890455  20791.318981     7.300212  368.516441    564.308654
# 1  3.716080  129.422921  18630.057858     6.635246         NaN    592.885359
# 2  8.099124  224.236259  19909.541732     9.275884         NaN    418.606213
# 3  8.316766  214.373394  22018.417441     8.059332  356.886136    363.266516
# 4  9.092223  181.101509  17978.986339     6.546600  310.135738    398.410813
#
#    Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0       10.379783        86.990970   2.963135           0
# 1       15.180013        56.329076   4.500656           0
# 2       16.868637        66.420093   3.055934           0
# 3       18.436524       100.341674   4.628771           0
# 4       11.558279        31.997993   4.075075           0

# %% [markdown]
# ### Variables & Data Types

# %%
# Variables are containers
# Data Types are values

# %%
print(5)
# Out:
# 5

# %%
print("Adele")
# Out:
# Adele

# %%
name = "Adele" # Variable containing Adele

# %%
print(name)
# Out:
# Adele

# %%
my_name = "Pablo" # Variable containing my name
print(my_name)
# Out:
# Pablo

# %%
fav_number = 26 # Variable containing a number
print(fav_number)
# Out:
# 26

# %%
my_name = ("Pablo")

# %%
print(my_name)
# Out:
# Pablo

# %%
type(my_name)
# Out:
# str

# %% [markdown]
# ### Naming & Using Variables

# %%
# Rules and guidelines for using and naming variables

# %%
# 1. Variables can contain only letters, numbers,
# and underscores. 
# You can't start a variable with a number

# %%
my_name1 = "Peter"

# %%
_name = "Pablo"

# %%
26_name = "Pablo"
# Out:
#   Cell In[45], line 1
#     26_name = "Pablo"
#       ^
# SyntaxError: invalid decimal literal

# %%
# 2. Spaces are not allowed in variable names
# Underscores can be used

# %%
my name = "Pablo"
# Out:
#   Cell In[47], line 1
#     my name = "Pablo"
#        ^
# SyntaxError: invalid syntax

# %%
# 3. Avoid using Python keywords and function names
# as variable names

# %%
num = [23,45,67]

# %%
sum(num)
# Out:
# 135

# %%
sum = 26

# %%
sum(num)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 sum(num)
#
# TypeError: 'int' object is not callable

# %%
help("keywords")
# Out:
# Here is a list of the Python keywords.  Enter any keyword to get more help.
#
# False               class               from                or
# None                continue            global              pass
# True                def                 if                  raise
# and                 del                 import              return
# as                  elif                in                  try
# assert              else                is                  while
# async               except              lambda              with
# await               finally             nonlocal            yield
# break               for                 not

# %%
print(sum)
# Out:
# 26

# %%
del sum

# %%
sum(num)
# Out:
# 135

# %% [markdown]
# #### String Methods

# %%
name = "Pablo" # A variable containing a string

# %%
print(name)
# Out:
# Pablo

# %%
job_pablo = "Data Science Educator" # Another variable containing a series of characters

# %%
type(job_pablo) # The type function
# Out:
# str

# %%
dir(job_pablo) # The dir function
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
# ...

# %%
print(job_pablo)
# Out:
# Data Science Educator

# %%
print(job_pablo.upper()) # Using the upper string method
# Out:
# DATA SCIENCE EDUCATOR

# %%
# ?job_pablo.upper # The documentation for the upper method
# Out:
# Signature: job_pablo.upper()
# Docstring: Return a copy of the string converted to uppercase.
# Type:      builtin_function_or_method

# %%
# ?job_pablo.zfill # The documentation of the zfill method
# Out:
# Signature: job_pablo.zfill(width, /)
# Docstring:
# Pad a numeric string with zeros on the left, to fill a field of the given width.
#
# The string is never truncated.
# Type:      builtin_function_or_method

# %%
# ?job_pablo.split # The documentation of the split method
# Out:
# Signature: job_pablo.split(sep=None, maxsplit=-1)
# Docstring:
# Return a list of the substrings in the string, using sep as the separator string.
#
#   sep
#     The separator used to split the string.
#
#     When set to None (the default value), will split on any whitespace
#     character (including \n \r \t \f and spaces) and will discard
#     empty strings from the result.
#   maxsplit
#     Maximum number of splits.
#     -1 (the default value) means no limit.
#
# Splitting starts at the front of the string and works to the end.
#
# Note, str.split() is mainly useful for data that has been intentionally
# delimited.  With natural text that includes punctuation, consider using
# the regular expression module.
# Type:      builtin_function_or_method

# %%
job_pablo.upper() # Using the upper method
# Out:
# 'DATA SCIENCE EDUCATOR'

# %%
# ?job_pablo.replace # The documentation of the replace method
# Out:
# Signature: job_pablo.replace(old, new, count=-1, /)
# Docstring:
# Return a copy with all occurrences of substring old replaced by new.
#
#   count
#     Maximum number of occurrences to replace.
#     -1 (the default value) means replace all occurrences.
#
# If the optional argument count is given, only the first count occurrences are
# replaced.
# Type:      builtin_function_or_method

# %%
print(job_pablo)
# Out:
# Data Science Educator

# %%
job_pablo_update = job_pablo.replace('Educator', 'Instructor')

# %%
# ?job_pablo.index
# Out:
# Docstring:
# S.index(sub[, start[, end]]) -> int
#
# Return the lowest index in S where substring sub is found,
# such that sub is contained within S[start:end].  Optional
# arguments start and end are interpreted as in slice notation.
#
# Raises ValueError when the substring is not found.
# Type:      builtin_function_or_method

# %%
job_pablo_update.index('Instructor') # Using the index method
# Out:
# 13

# %%
fav_num = 26 # A variable containing a number

# %%
dir(fav_num) # Method for a numerical datatype
# Out:
# ['__abs__',
#  '__add__',
#  '__and__',
#  '__bool__',
#  '__ceil__',
#  '__class__',
#  '__delattr__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__float__',
#  '__floor__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__index__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__invert__',
#  '__le__',
#  '__lshift__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
#  '__or__',
#  '__pos__',
#  '__pow__',
#  '__radd__',
#  '__rand__',
#  '__rdivmod__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rfloordiv__',
#  '__rlshift__',
#  '__rmod__',
#  '__rmul__',
#  '__ror__',
#  '__round__',
#  '__rpow__',
#  '__rrshift__',
#  '__rshift__',
#  '__rsub__',
#  '__rtruediv__',
#  '__rxor__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__truediv__',
#  '__trunc__',
# ...

# %% [markdown]
# #### Introduction to Lists

# %%
# Create a simple list
# This is a list of list
work_list = [
    ["Kpokpo", "Chioma", "Daddy's Girl"],
    ["Normal", "Aniekan", "Budding Data Scientist"],
    ["Not Sure", "Maryam", "Student"]
]

# %%
daddy_girl =  ["Kpokpo", "Chioma", "Daddy's Girl"] # A simple list

# %%
import pandas as pd # A data manipulation package

# %%
df = pd.DataFrame(work_list, columns=["Garri Type", "Name", "Profession"])

# %%
df
# Out:
#   Garri Type     Name              Profession
# 0     Kpokpo   Chioma            Daddy's Girl
# 1     Normal  Aniekan  Budding Data Scientist
# 2   Not Sure   Maryam                 Student

# %% [markdown]
# ##### *Attributes of a list*

# %%
# It is mutable
# It is sequential 
# Use a pair of square brackets to create a list

# %%
print(daddy_girl)
# Out:
# ['Kpokpo', 'Chioma', "Daddy's Girl"]

# %%
daddy_girl[1] = 'Ivy' # A list is mutable

# %%
daddy_girl
# Out:
# ['Kpokpo', 'Ivy', "Daddy's Girl"]

# %%
dir(daddy_girl) # List methods
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
# ?daddy_girl.append
# Out:
# Signature: daddy_girl.append(object, /)
# Docstring: Append object to the end of the list.
# Type:      builtin_function_or_method

# %%
daddy_girl.append("BMW") # Append an elent to the end of the list

# %%
daddy_girl.append(10000)

# %%
daddy_girl
# Out:
# ['Kpokpo', 'Ivy', "Daddy's Girl", 'BMW', 10000]

# %%
# ?daddy_girl.insert
# Out:
# Signature: daddy_girl.insert(index, object, /)
# Docstring: Insert object before index.
# Type:      builtin_function_or_method

# %%
daddy_girl.insert(1, 'David')

# %%
daddy_girl
# Out:
# ['Kpokpo', 'David', 'Ivy', "Daddy's Girl", 'BMW', 10000]

# %%
daddy_girl.append("BMW") # Run this cell three times

# %%
daddy_girl
# Out:
# ['Kpokpo', 'David', 'Ivy', "Daddy's Girl", 'BMW', 10000, 'BMW', 'BMW', 'BMW']

# %%
# ?daddy_girl.remove
# Out:
# Signature: daddy_girl.remove(value, /)
# Docstring:
# Remove first occurrence of value.
#
# Raises ValueError if the value is not present.
# Type:      builtin_function_or_method

# %%
# ?daddy_girl.pop
# Out:
# Signature: daddy_girl.pop(index=-1, /)
# Docstring:
# Remove and return item at index (default last).
#
# Raises IndexError if list is empty or index is out of range.
# Type:      builtin_function_or_method

# %%
daddy_girl
# Out:
# ['Kpokpo', 'David', 'Ivy', "Daddy's Girl", 'BMW', 10000, 'BMW', 'BMW', 'BMW']

# %%
daddy_girl.remove('BMW')

# %%
daddy_girl
# Out:
# ['Kpokpo', 'David', 'Ivy', "Daddy's Girl", 10000, 'BMW', 'BMW', 'BMW']

# %%
daddy_girl.pop()
# Out:
# 'BMW'

# %%
daddy_girl
# Out:
# ['Kpokpo', 'David', 'Ivy', "Daddy's Girl", 10000, 'BMW', 'BMW']

# %% [markdown]
# #### List Comprehension

# %%
# Use list comprehension to remove two elements at the same time

# %%
bm = ['BMW']

# %%
type(bm)
# Out:
# list

# %%
daddy_girl = [x for x in daddy_girl if x not in bm]

# %%
daddy_girl
# Out:
# ['Kpokpo', 'David', 'Ivy', "Daddy's Girl", 10000]

# %%
num_list = [3,4,5,6] # Another example of list comprehension

# %%
[x ** 2 for x in num_list]
# Out:
# [9, 16, 25, 36]

# %%
for x in num_list:
    print(x ** 2)
# Out:
# 9
# 16
# 25
# 36

# %%
list_numbers = [13,24,50]

# %%
list_numbers * 2
# Out:
# [13, 24, 50, 13, 24, 50]

# %%
import numpy as np

# %%
list_numbers_array = np.array(list_numbers)

# %%
list_numbers_array
# Out:
# array([13, 24, 50])

# %%
list_numbers_array * 2
# Out:
# array([ 26,  48, 100])

# %% [markdown]
# #### Numeric Data Types

# %%
# What we do with numbers:
# 1. Arithmetic Calculations
# 2. Store Measurements 
# 3. Work with Money
# 4. Track quantities

# %% [markdown]
# #### Numeric Data Types in Python

# %%
# int - Whole Number
# float - Decimal

# %%
# ints and floats 
4
# Out:
# 4

# %%
45 + 56
# Out:
# 101

# %%
# + - / *
num = 101

# %%
num * 2
# Out:
# 202

# %%
num - 100
# Out:
# 1

# %%
num = num + 100

# %%
print(num)
# Out:
# 201

# %%
5/2 # Division
# Out:
# 2.5

# %%
5//2 # Floored division
# Out:
# 2

# %%
5 % 2.9
# Out:
# 2.1

# %% [markdown]
# #### Tuples

# %% [markdown]
# ##### *Attributes of Tuples*

# %%
# Immutable 
# Indexable
# Ordered 
# Heterogeneous 
# ()
# Duplicates

# %%
tuple_num = 45,56, # Creating a simple Tuple

# %%
print(tuple_num)
# Out:
# (45, 56)

# %%
num_tuple_1 = (34,89,99) # Creating a simple Tuple using brackets

# %%
num_tuple_1
# Out:
# (34, 89, 99)

# %% [markdown]
# #### Casting a list to a tuple

# %%
num_list = [34,56,78,'Gobir']

# %%
type(num_list)
# Out:
# list

# %%
num_list_tuple = tuple(num_list) # Casting

# %%
print(num_list_tuple)
# Out:
# (34, 56, 78, 'Gobir')

# %%
dir(num_list)
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
dir(num_list_tuple)
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'count',
#  'index']

# %%
# Indexing a Tuple

# %%
num_list_tuple[1]
# Out:
# 56

# %%
num_list_tuple[1] = 100 # Tuples are Immutable
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 num_list_tuple[1] = 100
#
# TypeError: 'tuple' object does not support item assignment

# %%
num_tuple_1
# Out:
# (34, 89, 99)

# %% [markdown]
# #### Tuple Methods

# %%
# ?num_tuple_1.count
# Out:
# Signature: num_tuple_1.count(value, /)
# Docstring: Return number of occurrences of value.
# Type:      builtin_function_or_method

# %%
# ?num_tuple_1.index
# Out:
# Signature: num_tuple_1.index(value, start=0, stop=9223372036854775807, /)
# Docstring:
# Return first index of value.
#
# Raises ValueError if the value is not present.
# Type:      builtin_function_or_method

# %%
print(num_tuple_1)
# Out:
# (34, 89, 99)

# %%
num_tuple_1.index(99)
# Out:
# 2

# %%
name_student = "Abdullahi"

# %%
type(num_list)

# %% [markdown]
# #### Python Dictionary

# %%
# Attributes
# 1. Key Value Pairs
# 2. Key - Immutable, Value - Mutable 
# 3. The columns are used to map keys to values
# 4. It is ordered 
# 5. It is indexable 
# 6. The keys are unique
# 7. It is heterogeneous 
# 8. It is wrapped in curly braces - Done

# %%
curly_brace = {"Pablo": "Data Professional"} # Creating a Dictionary

# %%
curly_brace[0] # Dictionary values are accessible using keys not index positions
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 curly_brace[0]
#
# KeyError: 0

# %%
curly_brace['Pablo']
# Out:
# 'Data Professional'

# %%
print(curly_brace)
# Out:
# {'Pablo': 'Data Professional'}

# %% [markdown]
# #### Game - Level 1: The Scroll of Records

# %% [markdown]
# Challenge:
# Create a dictionary to store details of a lost scroll with the following keys:
#
# title
#
# year
#
# author

# %% [markdown]
# #### Level 2: The Oracle's Inquiry
#
# ##### Challenge:
# ##### *The Oracle asks: What is the title of the scroll?*

# %% [markdown]
# #### Level 3: The Time Stone (Update the Year)
#
# ##### *Time travel updated the scroll’s year. Change your year*

# %% [markdown]
# #### Level 4: The Secret Key (Add a New Field)
#
# ##### *Add a key called location with the value "CoLab Archives"*

# %% [markdown]
# ### Assignment
#
# #### Submission deadline: 12th July, 11:59pm

# %% [markdown]
# #### *Task: Build a Student Profile with a Dictionary*
#
# ##### *Goal:*
#
#
# ##### *Learn how to create a dictionary, access its values, and update it — just like storing a row of data.*

# %% [markdown]
# ##### *Instructions:*
#
#
# ##### *Create a dictionary named student_profile with the following keys and values:*
#
# "name" → Your name
#
# "age" → Your age
#
# "country" → Your country
#
# "course" → "Data Science"
#
# Print out the dictionary.
#
# Access and print the "name" and "course" values.
#
# Update the "age" value to a new number.
#
# Add a new key "score" with a value of 90.
#
# Print out the final dictionary.
